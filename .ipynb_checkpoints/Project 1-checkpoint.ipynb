# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("pandas version:", pd.__version__)
print("matplotlib and seaborn imported successfully")
# Out:
# pandas version: 3.0.1
# matplotlib and seaborn imported successfully

# %%
# --- dataset paths setup for all analyses ---
import os

# base folder containing your extracted datasets (adjust if you used a different location)
BASE = "/Users/rexoghenerobo/Downloads/Datasets"

datasets = {
    "Macworld":      os.path.join(BASE, "macworld"),
    "IndianExpress": os.path.join(BASE, "indianexpress"),
    "Kaksplus":      os.path.join(BASE, "kaksplus"),
    "Uusisuomi":     os.path.join(BASE, "uusisuomi"),
    "German":        os.path.join(BASE, "german_dataset"),
}

# quick validation (run this cell to confirm paths)
print("Path validation:")
for name, path in datasets.items():
    exists = os.path.exists(path)
    print(f"{name:14} → {path}")
    print(f"   exists? {exists}")
    if exists:
        try:
            count = len([f for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))])
        except Exception:
            count = "?"
        print(f"   → {count} article subfolders found")

# %%
# 1. English dataset Macworld 

import os
import pandas as pd
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt

# Dataset folder path
# updated to use shared dictionary
dataset_path = datasets["Macworld"]

# Tags to analyse
tags_to_check = ["title", "h1", "h2", "h3", "h4", "p", "a", "strong", "em", "meta_keywords"]

# Text cleaning function
def clean_text(text):
    if not text:
        return ""
    text = text.lower()
    text = re.sub(r'[^\w\s]', ' ', text)  # Remove punctuation
    return " ".join(text.split())

# Function to count keyword occurrences (with debug)
def count_keywords(text_list, keywords, tag_name="", folder_name="", debug=False):
    combined_text = clean_text(" ".join([t.strip() for t in text_list if t]))
    
    if debug and combined_text:
        print(f"\n--- DEBUG: {folder_name} | Tag: <{tag_name}> ---")
        print(f"CLEANED WORDS: {combined_text[:200]}...")  # Show first 200 chars
    
    count = 0
    for k in keywords:
        k_clean = clean_text(k)
        if not k_clean:
            continue
        matches = re.findall(r'\b' + re.escape(k_clean) + r'\b', combined_text)
        if debug and len(matches) > 0:
            print(f"   [Match] '{k_clean}' found {len(matches)} times")
        count += len(matches)
    return count

# Initialize counters
total_tag_counts = {tag: 0 for tag in tags_to_check}
processed_folders = 0

print("Starting analysis of Macworld Dataset...\n")

# Loop through dataset folders
for folder_name in os.listdir(dataset_path):
    folder_full_path = os.path.join(dataset_path, folder_name)
    
    if not os.path.isdir(folder_full_path):
        continue
    
    html_file = os.path.join(folder_full_path, "index.html")
    tags_file = os.path.join(folder_full_path, "tags.txt")
    
    if not (os.path.exists(html_file) and os.path.exists(tags_file)):
        continue
    
    try:
        # Read keywords from tags.txt
        with open(tags_file, "r", encoding="utf-8", errors="ignore") as f:
            content = f.read().strip()
            parts = content.split(None, 1)
            keywords = [k.strip() for k in parts[1].split(",")] if len(parts) > 1 else []
        
        # Read and parse HTML
        with open(html_file, "r", encoding="utf-8", errors="ignore") as f:
            soup = BeautifulSoup(f.read(), "lxml")
        
        # Remove script/style elements
        for script_or_style in soup(["script", "style"]):
            script_or_style.decompose()
        
        # Extract text from HTML tags
        tags_data = {
            "title": [soup.title.get_text()] if soup.title else [],
            "h1": [h.get_text() for h in soup.find_all("h1")],
            "h2": [h.get_text() for h in soup.find_all("h2")],
            "h3": [h.get_text() for h in soup.find_all("h3")],
            "h4": [h.get_text() for h in soup.find_all("h4")],
            "p": [p.get_text() for p in soup.find_all("p")],
            "a": [a.get_text() for a in soup.find_all("a")],
            "strong": [s.get_text() for s in soup.find_all("strong")],
            "em": [e.get_text() for e in soup.find_all("em")],
            "meta_keywords": [m["content"] for m in soup.find_all("meta", attrs={"name":"keywords"})]
        }
        
        # Show debug for first folder
        show_debug = True if processed_folders == 0 else False
        
        # Count keywords per tag
        for tag in tags_to_check:
            total_tag_counts[tag] += count_keywords(tags_data[tag], keywords, tag, folder_name, debug=show_debug)
        
        if processed_folders == 0:
            input("\nReview the found words above, then press Enter to continue full analysis...")
        
        processed_folders += 1
        if processed_folders % 20 == 0:
            print(f"> {processed_folders} folders processed...")
    
    except Exception as e:
        print(f"! Error ({folder_name}): {e}")

# Final Tabulation
print(f"\n--- Analysis Completed: {processed_folders} pages analysed ---")

df = pd.DataFrame(list(total_tag_counts.items()), columns=["HTML Tag", "Keyword Occurrences"])

if df["Keyword Occurrences"].sum() > 0:
    df["Percentage"] = (df["Keyword Occurrences"] / df["Keyword Occurrences"].sum()) * 100
    df = df.sort_values(by="Keyword Occurrences", ascending=False).reset_index(drop=True)
    df["Importance Score"] = df["Keyword Occurrences"] / df["Keyword Occurrences"].max()
    print("\n" + df.to_string())
    
    # Visualization
    plt.figure(figsize=(10,6))
    plt.bar(df["HTML Tag"], df["Keyword Occurrences"], color='skyblue', edgecolor='navy')
    plt.ylabel("Keyword Occurrences")
    plt.xlabel("HTML Element Tag")
    plt.title("Macworld Dataset: HTML Tag Keyword Frequencies")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
else:
    print("No results found. Please check the tags.txt format or folder contents.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 11
#       7 import matplotlib.pyplot as plt
#       9 # Dataset folder path
#      10 # updated to use shared dictionary
# ---> 11 dataset_path = datasets["Macworld"]
#      13 # Tags to analyse
#      14 tags_to_check = ["title", "h1", "h2", "h3", "h4", "p", "a", "strong", "em", "meta_keywords"]
#
# NameError: name 'datasets' is not defined

# %%
# 2. English dataset IndianExpress (Debug + Keyword Reporting)

import os
import pandas as pd
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt

# Dataset folder path
dataset_path = datasets["IndianExpress"]

# Tags to analyse
tags_to_check = ["title", "h1", "h2", "h3", "h4", "p", "a", "strong", "em", "meta_keywords"]

# Text cleaning function
def clean_text(text):
    if not text:
        return ""
    text = text.lower()
    text = re.sub(r'[^\w\s]', ' ', text)  # Remove punctuation
    return " ".join(text.split())

# Function to count keyword occurrences (with debug)
def count_keywords(text_list, keywords, tag_name="", folder_name="", debug=False):
    combined_text = clean_text(" ".join([t.strip() for t in text_list if t]))
    
    if debug and combined_text:
        print(f"\n--- DEBUG: {folder_name} | Tag: <{tag_name}> ---")
        print(f"CLEANED WORDS: {combined_text[:200]}...")  # Show first 200 chars
    
    count = 0
    for k in keywords:
        k_clean = clean_text(k)
        if not k_clean:
            continue
        matches = re.findall(r'\b' + re.escape(k_clean) + r'\b', combined_text)
        if debug and len(matches) > 0:
            print(f"   [Match] '{k_clean}' found {len(matches)} times")
        count += len(matches)
    return count

# Initialize counters
total_tag_counts = {tag: 0 for tag in tags_to_check}
processed_folders = 0

print("Starting analysis of IndianExpress Dataset...\n")

# Loop through dataset folders
for folder_name in os.listdir(dataset_path):
    folder_full_path = os.path.join(dataset_path, folder_name)
    
    if not os.path.isdir(folder_full_path):
        continue
    
    html_file = os.path.join(folder_full_path, "index.html")
    tags_file = os.path.join(folder_full_path, "tags.txt")
    
    if not (os.path.exists(html_file) and os.path.exists(tags_file)):
        continue
    
    try:
        # Read keywords from tags.txt
        with open(tags_file, "r", encoding="utf-8", errors="ignore") as f:
            content = f.read().strip()
            parts = content.split(None, 1)
            keywords = [k.strip() for k in parts[1].split(",")] if len(parts) > 1 else []
        
        # Read and parse HTML
        with open(html_file, "r", encoding="utf-8", errors="ignore") as f:
            soup = BeautifulSoup(f.read(), "lxml")
        
        # Remove script/style elements
        for script_or_style in soup(["script", "style"]):
            script_or_style.decompose()
        
        # Extract text from HTML tags
        tags_data = {
            "title": [soup.title.get_text()] if soup.title else [],
            "h1": [h.get_text() for h in soup.find_all("h1")],
            "h2": [h.get_text() for h in soup.find_all("h2")],
            "h3": [h.get_text() for h in soup.find_all("h3")],
            "h4": [h.get_text() for h in soup.find_all("h4")],
            "p": [p.get_text() for p in soup.find_all("p")],
            "a": [a.get_text() for a in soup.find_all("a")],
            "strong": [s.get_text() for s in soup.find_all("strong")],
            "em": [e.get_text() for e in soup.find_all("em")],
            "meta_keywords": [m["content"] for m in soup.find_all("meta", attrs={"name":"keywords"})]
        }
        
        # Show debug for first folder
        show_debug = True if processed_folders == 0 else False
        
        # Count keywords per tag
        for tag in tags_to_check:
            total_tag_counts[tag] += count_keywords(tags_data[tag], keywords, tag, folder_name, debug=show_debug)
        
        if processed_folders == 0:
            input("\nReview the found words above, then press Enter to continue full analysis...")
        
        processed_folders += 1
        if processed_folders % 20 == 0:
            print(f"> {processed_folders} folders processed...")
    
    except Exception as e:
        print(f"! Error ({folder_name}): {e}")

# Final Tabulation
print(f"\n--- Analysis Completed: {processed_folders} pages analysed ---")

df = pd.DataFrame(list(total_tag_counts.items()), columns=["HTML Tag", "Keyword Occurrences"])

if df["Keyword Occurrences"].sum() > 0:
    df["Percentage"] = (df["Keyword Occurrences"] / df["Keyword Occurrences"].sum()) * 100
    df = df.sort_values(by="Keyword Occurrences", ascending=False).reset_index(drop=True)
    df["Importance Score"] = df["Keyword Occurrences"] / df["Keyword Occurrences"].max()
    print("\n" + df.to_string())
    
    # Visualization
    plt.figure(figsize=(10,6))
    plt.bar(df["HTML Tag"], df["Keyword Occurrences"], color='skyblue', edgecolor='navy')
    plt.ylabel("Keyword Occurrences")
    plt.xlabel("HTML Element Tag")
    plt.title("IndianExpress Dataset: HTML Tag Keyword Frequencies")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
else:
    print("No results found. Please check the tags.txt format or folder contents.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 # 2. English dataset IndianExpress (Debug + Keyword Reporting)
#       3 import os
# ----> 4 import pandas as pd
#       5 from bs4 import BeautifulSoup
#       6 import re
#
# ModuleNotFoundError: No module named 'pandas'

# %% [raw]
# # 1. Finnish dataset Kaksplus
#
# import os
# import pandas as pd
# from bs4 import BeautifulSoup
# import re
# import matplotlib.pyplot as plt
#
# # Dataset path
# # updated to use shared dictionary
# dataset_path = datasets["Kaksplus"]
#
# # Tags to analyse
# tags_to_check = ["title","h1","h2","h3","h4","p","a","strong","em","meta_keywords"]
#
# # Text cleaning function
# def clean_text(text):
#     if not text:
#         return ""
#     text = text.lower()
#     text = re.sub(r'[^\w\s]', ' ', text)  # Remove punctuation
#     return " ".join(text.split())
#
# # Function to count keyword occurrences (with debug)
# def count_keywords(text_list, keywords, tag_name="", folder_name="", debug=False):
#     combined_text = clean_text(" ".join([t.strip() for t in text_list if t]))
#
#     if debug and combined_text:
#         print(f"\n--- DEBUG: {folder_name} | Tag: <{tag_name}> ---")
#         print(f"CLEANED WORDS: {combined_text[:200]}...")  # Show first 200 chars
#
#     count = 0
#     for k in keywords:
#         k_clean = clean_text(k)
#         if not k_clean:
#             continue
#         matches = re.findall(r'\b' + re.escape(k_clean) + r'\b', combined_text)
#         if debug and len(matches) > 0:
#             print(f"   [Match] '{k_clean}' found {len(matches)} times")
#         count += len(matches)
#     return count
#
# # Initialize counters
# total_tag_counts = {tag:0 for tag in tags_to_check}
# processed_folders = 0
#
# print("Starting analysis of Kaksplus Dataset...\n")
#
# # Loop through folders
# for folder_name in os.listdir(dataset_path):
#     folder_path = os.path.join(dataset_path, folder_name)
#     if not os.path.isdir(folder_path):
#         continue
#
#     html_file = os.path.join(folder_path,"index.html")
#     tags_file = os.path.join(folder_path,"tags.txt")
#     if not (os.path.exists(html_file) and os.path.exists(tags_file)):
#         continue
#
#     try:
#         # Read keywords
#         with open(tags_file,"r",encoding="utf-8",errors="ignore") as f:
#             line = f.read().strip()
#             parts = line.split(None,1)
#             if len(parts)<2:
#                 continue
#             keywords = [k.strip() for k in parts[1].split(",") if k.strip()]
#
#         # Read HTML
#         with open(html_file,"r",encoding="utf-8",errors="ignore") as f:
#             soup = BeautifulSoup(f.read(),"lxml")
#
#         # Extract tags
#         tags_data = {
#             "title":[soup.title.get_text()] if soup.title else [],
#             "h1":[h.get_text() for h in soup.find_all("h1")],
#             "h2":[h.get_text() for h in soup.find_all("h2")],
#             "h3":[h.get_text() for h in soup.find_all("h3")],
#             "h4":[h.get_text() for h in soup.find_all("h4")],
#             "p":[p.get_text() for p in soup.find_all("p")],
#             "a":[a.get_text() for a in soup.find_all("a")],
#             "strong":[s.get_text() for s in soup.find_all("strong")],
#             "em":[e.get_text() for e in soup.find_all("em")],
#             "meta_keywords":[m["content"] for m in soup.find_all("meta",attrs={"name":"keywords"})]
#         }
#
#         # Show debug for first folder
#         show_debug = True if processed_folders == 0 else False
#
#         # Count keywords per tag
#         for tag in tags_to_check:
#             total_tag_counts[tag]+=count_keywords(tags_data[tag],keywords, tag, folder_name, debug=show_debug)
#
#         if processed_folders==0:
#             input("\nReview the found words above, then press Enter to continue full analysis...")
#
#         processed_folders+=1
#         if processed_folders%20==0:
#             print(f"> {processed_folders} folders processed...")
#     except Exception as e:
#         print(f"! Error ({folder_name}): {e}")
#
# # Final tabulation of Kaksplus
# print(f"\n--- Analysis Completed: {processed_folders} pages analysed ---")
#
# df = pd.DataFrame(list(total_tag_counts.items()), columns=["HTML Tag","Keyword Occurrences"])
# if df["Keyword Occurrences"].sum()>0:
#     df["Percentage"]=(df["Keyword Occurrences"]/df["Keyword Occurrences"].sum())*100
#     df=df.sort_values(by="Keyword Occurrences",ascending=False).reset_index(drop=True)
#     df["Importance Score"]=df["Keyword Occurrences"]/df["Keyword Occurrences"].max()
#     print("\n"+df.to_string())
#     # visualization
#     plt.figure(figsize=(10,6))
#     plt.bar(df["HTML Tag"],df["Keyword Occurrences"],color='skyblue',edgecolor='navy')
#     plt.ylabel("Keyword Occurrences")
#     plt.xlabel("HTML Element Tag")
#     plt.title("Kaksplus Dataset: HTML Tag Keyword Frequencies")
#     plt.grid(axis='y',linestyle='--',alpha=0.7)
#     plt.show()
# else:
#     print("No results found. Please check the tags.txt format or folder contents.")

# %%
# 2. Finnish dataset Uusisuomi 
import os
import pandas as pd
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt

# Dataset path
dataset_path = r"C:\Users\Koti\Desktop\Data analytics assignments\Datasets\uusisuomi"

# Tags to analyse
tags_to_check = ["title","h1","h2","h3","h4","p","a","strong","em","meta_keywords"]

# Text cleaning function
def clean_text(text):
    if not text:
        return ""
    text = text.lower()
    text = re.sub(r'[^\w\s]', ' ', text)  # Remove punctuation
    return " ".join(text.split())

# Function to count keyword occurrences (with debug)
def count_keywords(text_list, keywords, tag_name="", folder_name="", debug=False):
    combined_text = clean_text(" ".join([t.strip() for t in text_list if t]))
    
    if debug and combined_text:
        print(f"\n--- DEBUG: {folder_name} | Tag: <{tag_name}> ---")
        print(f"CLEANED WORDS: {combined_text[:200]}...")  # Show first 200 chars
    
    count = 0
    for k in keywords:
        k_clean = clean_text(k)
        if not k_clean:
            continue
        matches = re.findall(r'\b' + re.escape(k_clean) + r'\b', combined_text)
        if debug and len(matches) > 0:
            print(f"   [Match] '{k_clean}' found {len(matches)} times")
        count += len(matches)
    return count

# Initialize counters
total_tag_counts = {tag:0 for tag in tags_to_check}
processed_folders = 0

print("Starting analysis of Uusisuomi Dataset...\n")

# Loop through folders
for folder_name in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder_name)
    if not os.path.isdir(folder_path):
        continue
    
    html_file = os.path.join(folder_path,"index.html")
    tags_file = os.path.join(folder_path,"tags.txt")
    if not (os.path.exists(html_file) and os.path.exists(tags_file)):
        continue
    
    try:
        # Read keywords
        with open(tags_file,"r",encoding="utf-8",errors="ignore") as f:
            line = f.read().strip()
            parts = line.split(None,1)
            if len(parts)<2:
                continue
            keywords = [k.strip() for k in parts[1].split(",") if k.strip()]
        
        # Read HTML
        with open(html_file,"r",encoding="utf-8",errors="ignore") as f:
            soup = BeautifulSoup(f.read(),"lxml")
        
        # Extract tags
        tags_data = {
            "title":[soup.title.get_text()] if soup.title else [],
            "h1":[h.get_text() for h in soup.find_all("h1")],
            "h2":[h.get_text() for h in soup.find_all("h2")],
            "h3":[h.get_text() for h in soup.find_all("h3")],
            "h4":[h.get_text() for h in soup.find_all("h4")],
            "p":[p.get_text() for p in soup.find_all("p")],
            "a":[a.get_text() for a in soup.find_all("a")],
            "strong":[s.get_text() for s in soup.find_all("strong")],
            "em":[e.get_text() for e in soup.find_all("em")],
            "meta_keywords":[m["content"] for m in soup.find_all("meta",attrs={"name":"keywords"})]
        }
        
        # Show debug for first folder
        show_debug = True if processed_folders == 0 else False
        
        # Count keywords per tag
        for tag in tags_to_check:
            total_tag_counts[tag]+=count_keywords(tags_data[tag],keywords, tag, folder_name, debug=show_debug)
        
        if processed_folders==0:
            input("\nReview the found words above, then press Enter to continue full analysis...")
        
        processed_folders+=1
        if processed_folders%20==0:
            print(f"> {processed_folders} folders processed...")
    
    except Exception as e:
        print(f"! Error ({folder_name}): {e}")

# Final Tabulation
print(f"\n--- Analysis Completed: {processed_folders} pages analysed ---")

df = pd.DataFrame(list(total_tag_counts.items()),columns=["HTML Tag","Keyword Occurrences"])

if df["Keyword Occurrences"].sum()>0:
    df["Percentage"]=(df["Keyword Occurrences"]/df["Keyword Occurrences"].sum())*100
    df=df.sort_values(by="Keyword Occurrences",ascending=False).reset_index(drop=True)
    df["Importance Score"]=df["Keyword Occurrences"]/df["Keyword Occurrences"].max()
    print(df.to_string())
    
    # Plot
    plt.figure(figsize=(10,6))
    plt.bar(df["HTML Tag"],df["Keyword Occurrences"], color='skyblue', edgecolor='navy')
    plt.ylabel("Keyword Occurrences")
    plt.xlabel("HTML Element Tag")
    plt.title("Uusisuomi Dataset: HTML Tag Keyword Frequencies")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
else:
    print("No results found. Check tags.txt format.")
# Out:
# Starting analysis of Uusisuomi Dataset...
#
#
# --- DEBUG: autot--102310-uusi-kiinalainen-rengasmerkki-tulossa-suomeen | Tag: <title> ---
# CLEANED WORDS: uusi kiinalainen rengasmerkki tulossa suomeen uusi suomi...
#    [Match] 'rengasmerkki' found 1 times
#
# --- DEBUG: autot--102310-uusi-kiinalainen-rengasmerkki-tulossa-suomeen | Tag: <h1> ---
# CLEANED WORDS: uusi kiinalainen rengasmerkki tulossa suomeen...
#    [Match] 'rengasmerkki' found 1 times
#
# --- DEBUG: autot--102310-uusi-kiinalainen-rengasmerkki-tulossa-suomeen | Tag: <h2> ---
# CLEANED WORDS: hakulomake hakulomake päävalikko toissijainen valikko aiheita tänään tuoreimmat kommentit uuden suomen yrityskanava mainos autotodayn koeajot tuoreimmat autouutiset poiminnat uuden suomen blogit yrity...
#
# --- DEBUG: autot--102310-uusi-kiinalainen-rengasmerkki-tulossa-suomeen | Tag: <h4> ---
# CLEANED WORDS: autotoday testasi ford focus wagon titanium isomman oloinen tässä uusi suomi autot osion ensimmäisen vuoden suosituimmat koeajot autotoday testasi vw polo gti 1 8 tsi dsg sporttisin polo autotoday tes...
#
# --- DEBUG: autot--102310-uusi-kiinalainen-rengasmerkki-tulossa-suomeen | Tag: <p> ---
# CLEANED WORDS: varmaan piristää kilpailua tärkeintä on että renkaat on mustat ja pyöreät aikoinaan ddr ssä tehtyjä pneumant renkaita ei meinannut millään sada tasapainoon niinpä niitä käytettiin paljon peräkärryn re...
#
# --- DEBUG: autot--102310-uusi-kiinalainen-rengasmerkki-tulossa-suomeen | Tag: <a> ---
# CLEANED WORDS: hyppää pääsisältöön tietoa kirjautumisesta mediamyynti tilaa uutiskirje yhteystiedot kirjaudu etusivu uutiset kotimaa ulkomaat raha asuminen tiede terveys teknologia autot urheilu viihde videot puheen...
#    [Match] 'jukka heiskanen' found 1 times
#    [Match] 'kesärengas' found 1 times
#    [Match] 'antti heiskanen' found 1 times
#    [Match] 'renkaiden maahantuonti' found 1 times
#    [Match] 'talvirengas' found 1 times
#    [Match] 'pierre cohade' found 1 times
#    [Match] 'vannetukku' found 1 times
#    [Match] 'rengasmerkki' found 1 times
#    [Match] 'triangle' found 1 times
#    [Match] 'maansiirtorengas' found 1 times
#
# --- DEBUG: autot--102310-uusi-kiinalainen-rengasmerkki-tulossa-suomeen | Tag: <strong> ---
# CLEANED WORDS: tilaa tästä autotodayn ilmainen uutiskirje audi s3 toyota corolla ford transit connect volkswagen caddy renault trafic kia venga ford mondeo volvo v40 mercedes benz c mercedes benz c ford transit bmw ...
#
# --- DEBUG: autot--102310-uusi-kiinalainen-rengasmerkki-tulossa-suomeen | Tag: <em> ---
# CLEANED WORDS: tilaa tästä autotodayn ilmainen uutiskirje...
# Review the found words above, then press Enter to continue full analysis...
# > 20 folders processed...
# > 40 folders processed...
# > 60 folders processed...
# > 80 folders processed...
# > 100 folders processed...
# > 120 folders processed...
# > 140 folders processed...
# > 160 folders processed...
# > 180 folders processed...
# > 200 folders processed...
#
# --- Analysis Completed: 200 pages analysed ---
#         HTML Tag  Keyword Occurrences  Percentage  Importance Score
# 0              a                 2438   61.210143          1.000000
# 1              p                 1021   25.633944          0.418786
# 2         strong                  223    5.598795          0.091468
# 3          title                  101    2.535777          0.041427
# 4             h1                  100    2.510670          0.041017
# 5             em                   46    1.154908          0.018868
# 6             h4                   44    1.104695          0.018048
# 7             h2                   10    0.251067          0.004102
# 8             h3                    0    0.000000          0.000000
# 9  meta_keywords                    0    0.000000          0.000000

# %%
# German dataset 


import os
import pandas as pd
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt
import warnings
from bs4 import XMLParsedAsHTMLWarning

# Suppress XML/HTML mismatch warnings
warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)

dataset_path = r"C:\Users\Koti\Desktop\Data analytics assignments\Datasets\german_dataset"
tags_to_check = ["title", "h1", "h2", "h3", "h4", "p", "a", "strong", "em", "meta_keywords"]

# --- Text Cleaning Function (Word Preprocessing) ---
def clean_text(text):
    if not text:
        return ""
    text = text.lower()
    # Removes punctuation but keeps German characters (ä, ö, ü, ß) and numbers
    text = re.sub(r'[^\w\s]', ' ', text)
    return " ".join(text.split())

def count_keywords(text_list, keywords, tag_name="", folder_name="", debug=False):
    # Join and clean the text from HTML
    combined_text = clean_text(" ".join([t.strip() for t in text_list if t]))
    
    if debug and combined_text:
        print(f"\n--- DEBUG: {folder_name} | Tag: <{tag_name}> ---")
        print(f"CLEANED WORDS: {combined_text[:200]}...")

    count = 0
    for k in keywords:
        # Clean the keyword from GT.txt to ensure match
        k = clean_text(k)
        if k:
            # Use regex boundaries \b to match exact words only
            matches = re.findall(r'\b' + re.escape(k) + r'\b', combined_text)
            if debug and len(matches) > 0:
                print(f"   [Match] '{k}' found {len(matches)} times")
            count += len(matches)
    return count

total_tag_counts = {tag: 0 for tag in tags_to_check}
processed_folders = 0

print("Starting analysis of German Dataset...\n")

for folder_name in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder_name)
    if not os.path.isdir(folder_path):
        continue
    
    html_file = os.path.join(folder_path, "HTML.txt")  # German dataset filename
    tags_file = os.path.join(folder_path, "GT.txt")    # Ground-truth filename
    
    if not (os.path.exists(html_file) and os.path.exists(tags_file)):
        continue
        
    try:
        # 1. Read Keywords from GT.txt
        with open(tags_file, "r", encoding="utf-8", errors="ignore") as f:
            content = f.read().strip()
            # Handle different GT.txt formats (comma-separated or list)
            if "," in content:
                # If it follows your specific parts[1] logic:
                parts = content.split(None, 1)
                keywords = [k.strip() for k in parts[1].split(",") if k.strip()] if len(parts) > 1 else []
            else:
                keywords = [k.strip() for k in content.splitlines() if k.strip()]

        # 2. Read and Parse HTML.txt
        with open(html_file, "r", encoding="utf-8", errors="ignore") as f:
            soup = BeautifulSoup(f.read(), "html.parser") # Use html.parser for flexibility

        # Remove script and style elements (Cleaning JavaScript noise)
        for script_or_style in soup(["script", "style"]):
            script_or_style.decompose()

        tags_data = {
            "title": [soup.title.get_text()] if soup.title else [],
            "h1": [h.get_text() for h in soup.find_all("h1")],
            "h2": [h.get_text() for h in soup.find_all("h2")],
            "h3": [h.get_text() for h in soup.find_all("h3")],
            "h4": [h.get_text() for h in soup.find_all("h4")],
            "p": [p.get_text() for p in soup.find_all("p")],
            "a": [a.get_text() for a in soup.find_all("a")],
            "strong": [s.get_text() for s in soup.find_all("strong")],
            "em": [e.get_text() for e in soup.find_all("em")],
            "meta_keywords": [m["content"] for m in soup.find_all("meta", attrs={"name": "keywords"})]
        }

        # Show cleaned words for the very first folder processed
        show_debug = True if processed_folders == 0 else False

        for tag in tags_to_check:
            total_tag_counts[tag] += count_keywords(tags_data[tag], keywords, tag, folder_name, debug=show_debug)
        
        if processed_folders == 0:
            input("\nReview the cleaned words above, then press Enter to finish the full analysis...")

        processed_folders += 1
        if processed_folders % 20 == 0:
            print(f"> {processed_folders} folders processed...")
            
    except Exception as e:
        print(f"! Error ({folder_name}): {e}")

# --- Final Tabulation ---
print(f"\n--- Analysis Completed: {processed_folders} pages analysed ---")
df = pd.DataFrame(list(total_tag_counts.items()), columns=["HTML Tag", "Keyword Occurrences"])

if df["Keyword Occurrences"].sum() > 0:
    df["Percentage"] = (df["Keyword Occurrences"] / df["Keyword Occurrences"].sum()) * 100
    df = df.sort_values(by="Keyword Occurrences", ascending=False).reset_index(drop=True)
    df["Importance Score"] = df["Keyword Occurrences"] / df["Keyword Occurrences"].max()
    
    print("\n" + df.to_string())
    
    # --- Visualization ---
    plt.figure(figsize=(10, 6))
    plt.bar(df["HTML Tag"], df["Keyword Occurrences"], color='skyblue', edgecolor='navy')
    plt.ylabel("Keyword Occurrences")
    plt.xlabel("HTML Element Tag")
    plt.title("German Dataset: HTML Tag Keyword Frequencies")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
else:
    print("No results found. Check GT.txt format or folder contents.")
# Out:
# Starting analysis of German Dataset...
#
#
# --- DEBUG: 0 | Tag: <title> ---
# CLEANED WORDS: sprache bildung und erfolg neuere erkenntnisse aus der forschung die perspektive der bildungsforschung goethe institut...
#    [Match] 'forschung' found 1 times
#    [Match] 'bildung' found 1 times
#
# --- DEBUG: 0 | Tag: <h1> ---
# CLEANED WORDS: neuere erkenntnisse aus der forschung die perspektive der bildungsforschung sprache bildung und erfolg...
#    [Match] 'forschung' found 1 times
#    [Match] 'bildung' found 1 times
#
# --- DEBUG: 0 | Tag: <h2> ---
# CLEANED WORDS: deutsche sprache sprache und herkunft felder der bildungsforschung...
#
# --- DEBUG: 0 | Tag: <h3> ---
# CLEANED WORDS: anmeldung deutsche sprache kultur über uns autorin links zum thema standpunkte...
#
# --- DEBUG: 0 | Tag: <h4> ---
# CLEANED WORDS: magazin sprache deutschkurse und deutschprüfungen deutsch unterrichten kostenlos deutsch üben unser engagement für deutsch warum deutsch lernen willkommen deutschlernen für flüchtlinge europa architek...
#    [Match] 'deutsch' found 4 times
#    [Match] 'bildung' found 1 times
#
# --- DEBUG: 0 | Tag: <p> ---
# CLEANED WORDS: welche bedeutung haben sprachliche fähigkeiten für bildungserfolg und darüber hinausgehend für gesellschaftliche teilhabe dies ist eine leitfrage der bildungsforschung zur sprachentwicklung eine suche...
#    [Match] 'schule' found 3 times
#    [Match] 'deutsch' found 3 times
#    [Match] 'als' found 6 times
#    [Match] 'zweitsprache' found 2 times
#    [Match] 'forschung' found 1 times
#    [Match] 'gogolin' found 3 times
#
# --- DEBUG: 0 | Tag: <a> ---
# CLEANED WORDS: direkt zum inhalt springen alt 1 direkt zur sekundärnavigation springen alt 3 direkt zur hauptnavigation springen alt 2 logo goethe institut schließen john george mein goethe de abmelden mein goethe d...
#    [Match] 'deutsch' found 20 times
#    [Match] 'als' found 3 times
#    [Match] 'zweitsprache' found 1 times
#    [Match] 'forschung' found 1 times
#    [Match] 'bildung' found 4 times
#
# --- DEBUG: 0 | Tag: <meta_keywords> ---
# CLEANED WORDS: migration schule deutsch als zweitsprache forschung bildung kindergarten gogolin sprachtest...
#    [Match] 'schule' found 1 times
#    [Match] 'deutsch' found 1 times
#    [Match] 'als' found 1 times
#    [Match] 'zweitsprache' found 1 times
#    [Match] 'forschung' found 1 times
#    [Match] 'bildung' found 1 times
#    [Match] 'kindergarten' found 1 times
#    [Match] 'gogolin' found 1 times
#    [Match] 'sprachtest' found 1 times
# Review the cleaned words above, then press Enter to finish the full analysis...
# > 20 folders processed...
# > 40 folders processed...
# > 60 folders processed...
# > 80 folders processed...
#
# --- Analysis Completed: 86 pages analysed ---
#
#         HTML Tag  Keyword Occurrences  Percentage  Importance Score
# 0  meta_keywords                 3123   34.800535          1.000000
# 1              a                 2845   31.702697          0.910983
# 2              p                 1505   16.770671          0.481908
# 3             h3                  471    5.248496          0.150817
# 4          title                  393    4.379318          0.125841
# 5             h2                  233    2.596390          0.074608
# 6             h1                  217    2.418097          0.069484
# 7         strong                   93    1.036327          0.029779
# 8             h4                   74    0.824604          0.023695
# 9             em                   20    0.222866          0.006404

# %%
import os
import re
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# Dataset paths - refer to BASE defined earlier
try:
    BASE
except NameError:
    BASE = "/Users/rexoghenerobo/Downloads/Datasets"

datasets = {
    "Macworld": os.path.join(BASE, "macworld"),
    "IndianExpress": os.path.join(BASE, "indianexpress"),
    "Kaksplus": os.path.join(BASE, "kaksplus"),
    "Uusisuomi": os.path.join(BASE, "uusisuomi"),
    "German": os.path.join(BASE, "german_dataset")
}

tags_to_check = ["title", "h1", "h2", "h3", "h4", "p", "a", "strong", "em", "meta_keywords", "url_path"]

def clean_text(text):
    if not text: return ""
    text = text.lower()
    text = re.sub(r'[^\w\s]', ' ', text)
    return " ".join(text.split())


def count_keywords(combined_text, keywords):
    count = 0
    combined_text = clean_text(combined_text)
    for k in keywords:
        k_clean = clean_text(k)
        if not k_clean: continue
        matches = re.findall(r'\b' + re.escape(k_clean) + r'\b', combined_text)
        count += len(matches)
    return count

# All results accumulator
master_results = {tag: 0 for tag in tags_to_check}

for ds_name, ds_path in datasets.items():
    print(f"Analyzing {ds_name}...")
    for folder_name in os.listdir(ds_path):
        folder_full_path = os.path.join(ds_path, folder_name)
        if not os.path.isdir(folder_full_path): continue

        # filenames vary (German uses HTML.txt/GT.txt)
        html_file = os.path.join(folder_full_path, "index.html") if ds_name != "German" else os.path.join(folder_full_path, "HTML.txt")
        tags_file = os.path.join(folder_full_path, "tags.txt") if ds_name != "German" else os.path.join(folder_full_path, "GT.txt")
        if not (os.path.exists(html_file) and os.path.exists(tags_file)): continue

        try:
            with open(tags_file, "r", encoding="utf-8", errors="ignore") as f:
                content = f.read().strip()
                if "," in content:
                    parts = content.split(None, 1)
                    keywords = [k.strip() for k in parts[1].split(",")] if len(parts) > 1 else []
                else:
                    keywords = content.splitlines()

            with open(html_file, "r", encoding="utf-8", errors="ignore") as f:
                soup = BeautifulSoup(f.read(), "lxml")

            # URL path text
            url_text = folder_name.replace("-", " ").replace("_", " ")
            master_results["url_path"] += count_keywords(url_text, keywords)

            # Tag text counts
            master_results["title"] += count_keywords(soup.title.get_text() if soup.title else "", keywords)
            master_results["h1"] += count_keywords(" ".join([h.get_text() for h in soup.find_all("h1")]), keywords)
            master_results["h2"] += count_keywords(" ".join([h.get_text() for h in soup.find_all("h2")]), keywords)
            master_results["h3"] += count_keywords(" ".join([h.get_text() for h in soup.find_all("h3")]), keywords)
            master_results["h4"] += count_keywords(" ".join([h.get_text() for h in soup.find_all("h4")]), keywords)
            master_results["p"] += count_keywords(" ".join([p.get_text() for p in soup.find_all("p")]), keywords)
            master_results["a"] += count_keywords(" ".join([a.get_text() for a in soup.find_all("a")]), keywords)
            master_results["strong"] += count_keywords(" ".join([s.get_text() for s in soup.find_all("strong")]), keywords)
            master_results["em"] += count_keywords(" ".join([e.get_text() for e in soup.find_all("em")]), keywords)

            meta_text = " ".join([m["content"] for m in soup.find_all("meta", attrs={"name": re.compile(r'keywords|tags', re.I)}) if m.has_attr("content")])
            master_results["meta_keywords"] += count_keywords(meta_text, keywords)

        except Exception:
            continue

# Final table

df_final = pd.DataFrame(list(master_results.items()), columns=["HTML Tag", "Total Keyword Occurrences"])
df_final = df_final.sort_values(by="Total Keyword Occurrences", ascending=False)
df_final["Importance Score"] = df_final["Total Keyword Occurrences"] / df_final["Total Keyword Occurrences"].max()

print("\n--- MASTER ANALYSIS RESULT ---")
print(df_final.to_string())
df_final.to_csv("master_analysis_report.csv", index=False)
# Out:
# Analyzing Macworld...
# Analyzing IndianExpress...
# Analyzing Kaksplus...
# Analyzing Uusisuomi...
# Analyzing German...
#
# --- MASTER ANALYSIS RESULT ---
#          HTML Tag  Total Keyword Occurrences  Importance Score
# 6               a                      12725          1.000000
# 5               p                      11251          0.884165
# 9   meta_keywords                       8621          0.677485
# 0           title                       1270          0.099804
# 1              h1                       1111          0.087308
# 10       url_path                       1078          0.084715
# 2              h2                        945          0.074263
# 3              h3                        724          0.056896
# 7          strong                        519          0.040786
# 4              h4                        340          0.026719
# 8              em                        197          0.015481

# %%
# --- Member 3: compute normalized importance and Top‑10 output ---
import pandas as pd
from pathlib import Path

# df_final should already exist from the master analysis above
try:
    df_final
except NameError:
    print("df_final not defined, run the previous cell first.")
else:
    # make sure the output directory exists
    out = Path(BASE) / "member3_outputs"
    out.mkdir(exist_ok=True)

    # save global sorted results
    df_final.to_csv(out / "global_normalized_scores.csv", index=False)
    df_final.head(10).to_csv(out / "global_top10.csv", index=False)
    print("Global top‑10 saved to", out)
    display(df_final.head(10))

    # create a bar chart and save
    import matplotlib.pyplot as plt
    plt.figure(figsize=(10,5))
    plt.bar(df_final["HTML Tag"].head(10), df_final["Importance Score"].head(10), color='teal')
    plt.title("Global Top‑10 Tags by Importance Score")
    plt.ylabel("Importance Score")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(out / "global_top10_plot.png", dpi=200)
    plt.show()

# %%
import os
import re
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import warnings
from bs4 import XMLParsedAsHTMLWarning

# 1. SETUP & CONFIGURATION
warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)

# reuse BASE variable for paths
try:
    BASE
except NameError:
    BASE = "/Users/rexoghenerobo/Downloads/Datasets"

datasets = {
    "Macworld": os.path.join(BASE, "macworld"),
    "IndianExpress": os.path.join(BASE, "indianexpress"),
    "Kaksplus": os.path.join(BASE, "kaksplus"),
    "Uusisuomi": os.path.join(BASE, "uusisuomi"),
    "German": os.path.join(BASE, "german_dataset")
}

tags_to_track = ["title", "h1", "h2", "h3", "h4", "p", "a", "strong", "em", "meta_keywords", "url_components"]
master_results = {tag: 0 for tag in tags_to_track}

# 2. HELPER FUNCTIONS
def clean_text(text):
    """Clean text while preserving German/Finnish characters."""
    if not text: return ""
    text = text.lower()
    text = re.sub(r'[^\w\s]', ' ', text)
    return " ".join(text.split())

def count_keywords(text, keywords):
    """Counts exact occurrences of keywords in cleaned text."""
    if not text: return 0
    text_clean = clean_text(text)
    count = 0
    for kw in keywords:
        kw_clean = clean_text(kw)
        if not kw_clean: continue
        matches = re.findall(r'\b' + re.escape(kw_clean) + r'\b', text_clean)
        count += len(matches)
    return count

# (Further analysis code could follow here)
# Out:
# Starting Global Tag-Level Analysis...
# -> Analyzing Dataset: Macworld
# -> Analyzing Dataset: IndianExpress
# -> Analyzing Dataset: Kaksplus
# -> Analyzing Dataset: Uusisuomi
# -> Analyzing Dataset: German
#
# ==================================================
# MEMBER 2: FINAL TAG-LEVEL FREQUENCY REPORT
# ==================================================
#       HTML Tag  Keyword Occurrences  Percentage (%)  Importance Score
#              a                12725           32.40              1.00
#              p                11251           28.65              0.88
#  meta_keywords                 9107           23.19              0.72
#          title                 1271            3.24              0.10
#             h1                 1111            2.83              0.09
# url_components                 1078            2.75              0.08
#             h2                  948            2.41              0.07
#             h3                  724            1.84              0.06
#         strong                  519            1.32              0.04
#             h4                  340            0.87              0.03
#             em                  197            0.50              0.02

# %%
# Member 3: Per-Dataset Analysis (Add this cell)

import pandas as pd  # Ensure imported if not already

# Reset and run per-dataset
results_per_dataset = {}  # Dict to hold DF per dataset

for name, path in datasets.items():
    if not os.path.exists(path):
        continue
    
    # Initialize counters for this dataset
    dataset_results = {tag: 0 for tag in tags_to_track}
    
    # (Copy the folder iteration loop from the original code here, but use dataset_results instead of master_results)
    # ... [Paste the loop from line ~50 in the second cell: for folder_name in os.listdir(path): ... ]
    # Replace master_results[tag] += ... with dataset_results[tag] += ...
    # (Omit the print statements inside the loop for speed)
    
    # After the loop, create DF for this dataset
    df_dataset = pd.DataFrame(list(dataset_results.items()), columns=["HTML Tag", "Keyword Occurrences"])
    total_hits = df_dataset["Keyword Occurrences"].sum()
    if total_hits > 0:
        df_dataset["Percentage (%)"] = (df_dataset["Keyword Occurrences"] / total_hits * 100).round(2)
        max_val = df_dataset["Keyword Occurrences"].max()
        df_dataset["Importance Score"] = (df_dataset["Keyword Occurrences"] / max_val).round(2)
        df_dataset = df_dataset.sort_values(by="Keyword Occurrences", ascending=False).reset_index(drop=True)
    
    results_per_dataset[name] = df_dataset
    print(f"\n=== {name} Dataset Results ===")
    print(df_dataset.to_string(index=False))
    df_dataset.to_csv(f"{name}_tag_analysis.csv", index=False)  # Save per-dataset CSV

# Global remains as df_final (from original code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5 # Reset and run per-dataset
#       6 results_per_dataset = {}  # Dict to hold DF per dataset
# ----> 8 for name, path in datasets.items():
#       9     if not os.path.exists(path):
#      10         continue
#
# NameError: name 'datasets' is not defined

# %%
# Member 3: Refined Global Scores (Average across datasets)

# Combine all DFs
all_dfs = pd.concat(results_per_dataset.values(), keys=results_per_dataset.keys())
all_dfs = all_dfs.reset_index(level=0).rename(columns={'level_0': 'Dataset'})

# Group by tag and average scores (for cross-dataset consistency)
global_refined = all_dfs.groupby('HTML Tag')['Importance Score'].agg(['mean', 'std']).round(2)
global_refined = global_refined.sort_values(by='mean', ascending=False).reset_index()
global_refined.rename(columns={'mean': 'Avg Importance Score', 'std': 'Variability (Std Dev)'}, inplace=True)

print("\n=== Refined Global Scores (Averaged) ===")
print(global_refined.to_string(index=False))

# Save
global_refined.to_csv('member3_refined_scores.csv', index=False)

# Importance Score Formula (document in markdown cell):
# Score(tag, dataset) = Occurrences(tag) / Max_Occurrences(in dataset)
# Global Score(tag) = Average(Score(tag) across all datasets)
# This accounts for dataset size differences and language variations.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       1 # Member 3: Refined Global Scores (Average across datasets)
#       2
#       3 # Combine all DFs
# ----> 4 all_dfs = pd.concat(results_per_dataset.values(), keys=results_per_dataset.keys())
#       5 all_dfs = all_dfs.reset_index(level=0).rename(columns={'level_0': 'Dataset'})
#       7 # Group by tag and average scores (for cross-dataset consistency)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/reshape/concat.py:407, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     402 else:  # pragma: no cover
#     403     raise ValueError(
#     404         "Only can inner (intersect) or outer (union) join the other axis"
#     405     )
# --> 407 objs, keys, ndims = _clean_keys_and_objs(objs, keys)
#     409 if sort is lib.no_default:
#     410     if axis == 0:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/reshape/concat.py:808, in _clean_keys_and_objs(objs, keys)
#     805     objs = list(objs)
#     807 if len(objs) == 0:
# --> 808     raise ValueError("No objects to concatenate")
#     810 if keys is not None:
#     811     if not isinstance(keys, Index):
#
# ValueError: No objects to concatenate

# %%
# Member 3: Top 10 Ranking

df_top10 = global_refined[global_refined['Avg Importance Score'] > 0].head(10)
df_top10['Rank'] = range(1, len(df_top10) + 1)
df_top10 = df_top10[['Rank', 'HTML Tag', 'Avg Importance Score', 'Variability (Std Dev)']]

print("\n=== Member 3: Final Top 10 Ranked Tags ===")
print(df_top10.to_string(index=False))

# Export as Markdown for report (copy-paste into Word/Google Docs)
print("\nMarkdown Table:\n")
print(df_top10.to_markdown(index=False))

df_top10.to_csv('member3_top10.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Member 3: Top 10 Ranking
# ----> 3 df_top10 = global_refined[global_refined['Avg Importance Score'] > 0].head(10)
#       4 df_top10['Rank'] = range(1, len(df_top10) + 1)
#       5 df_top10 = df_top10[['Rank', 'HTML Tag', 'Avg Importance Score', 'Variability (Std Dev)']]
#
# NameError: name 'global_refined' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Bar chart: Scores per tag, grouped by dataset
plt.figure(figsize=(12, 6))
sns.barplot(data=all_dfs, x='HTML Tag', y='Importance Score', hue='Dataset')
plt.title('Importance Scores: Comparison Across Datasets')
plt.xticks(rotation=45)
plt.ylabel('Importance Score (0-1)')
plt.grid(axis='y')
plt.savefig('member3_comparison_chart.png')  # Save for report
plt.show()

# Validation: High consistency if std dev < 0.1; note language differences (e.g., Finnish/German may have more <strong> due to emphasis styles)
print("\nValidation Notes:")
for tag in df_top10['HTML Tag']:
    std = global_refined[global_refined['HTML Tag'] == tag]['Variability (Std Dev)'].values[0]
    print(f"- {tag}: Variability {std} (Low if <0.1, indicating consistency across languages)")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       4 # Bar chart: Scores per tag, grouped by dataset
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import os

home = "/Users/rexogehenerobo"
downloads = os.path.join(home, "Downloads")

# Option A
analytics_folder = os.path.join(downloads, "Project 1.ipynb")
datasets_a = os.path.join(analytics_folder, "Datasets")

# Option B
datasets_b = os.path.join(downloads, "Datasets")

print("Option A - full path:")
print(datasets_a)
print("  → exists?", os.path.exists(datasets_a))
if os.path.exists(datasets_a):
    print("  → subfolders:", os.listdir(datasets_a))

print("\nOption B - full path:")
print(datasets_b)
print("  → exists?", os.path.exists(datasets_b))
if os.path.exists(datasets_b):
    print("  → subfolders:", os.listdir(datasets_b))
# Out:
# Option A - full path:
# /Users/rexogehenerobo/Downloads/Project 1.ipynb/Datasets
#   → exists? False
#
# Option B - full path:
# /Users/rexogehenerobo/Downloads/Datasets
#   → exists? False
